# %% [markdown]
# The Nobel Prize has been among the most prestigious international awards since 1901. Each year, awards are bestowed in chemistry, literature, physics, physiology or medicine, economics, and peace. In addition to the honor, prestige, and substantial prize money, the recipient also gets a gold medal with an image of Alfred Nobel (1833 - 1896), who established the prize.
#
# ![](Nobel_Prize.png)
#
# The Nobel Foundation has made a dataset available of all prize winners from the outset of the awards from 1901 to 2023. The dataset used in this project is from the Nobel Prize API and is available in the `nobel.csv` file in the `data` folder.
#
# In this project, you'll get a chance to explore and answer several questions related to this prizewinning data. And we encourage you then to explore further questions that you're interested in!

# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Start coding here!

# %%
df=pd.read_csv('data/nobel.csv')
print(df.head(10))
# Out:
#    year    category  ...      death_city   death_country
# 0  1901   Chemistry  ...          Berlin         Germany
# 1  1901  Literature  ...        Châtenay          France
# 2  1901    Medicine  ...         Marburg         Germany
# 3  1901       Peace  ...          Heiden     Switzerland
# 4  1901       Peace  ...           Paris          France
# 5  1901     Physics  ...          Munich         Germany
# 6  1902   Chemistry  ...          Berlin         Germany
# 7  1902  Literature  ...  Charlottenburg         Germany
# 8  1902    Medicine  ...    Putney Heath  United Kingdom
# 9  1902       Peace  ...            Bern     Switzerland
#
# [10 rows x 18 columns]

# %%
top_gender=df["sex"].value_counts().index[0]
print(top_gender)
# Out:
# Male

# %%
top_country=df["birth_country"].value_counts().index[0]
print(top_country)
# Out:
# United States of America

# %%
df["decade"] = (np.floor(df["year"] / 10) * 10).astype(int)
df['us_born_winner'] = df['birth_country'] == "United States of America"

us_born_ratio_by_decade = df.groupby("decade", as_index=False)['us_born_winner'].mean().reset_index()
# print(type(us_born_ratio_by_decade))
highest_ratio = us_born_ratio_by_decade.loc[us_born_ratio_by_decade['us_born_winner'].idxmax()]

max_decade_usa = highest_ratio['decade'].astype(int)
print(max_decade_usa)
# Out:
# 2000

# %%
df['fem_winners'] = df["sex"] == 'Female'
female_winner = df.groupby(["decade", "category"])["fem_winners"].mean().reset_index()

max_winners_decade = female_winner.loc[female_winner["fem_winners"].idxmax()]
# print(max_winners_decade)
decade = max_winners_decade["decade"]
category = max_winners_decade["category"]

max_female_dict = {
    decade: 'Decade',
    "category": category
}
print(max_female_dict)
# Out:
# {2020: 'Decade', 'category': 'Literature'}

# %%
# Find first woman to win a Nobel Prize
nobel_woman = df[df["fem_winners"]]
sorted_data = nobel_woman.sort_values(by='year')
# print(sorted_data.head())

first_woman_name = sorted_data.iloc[0]["full_name"]
print(first_woman_name)
first_woman_category = sorted_data.iloc[0]["category"]
print(first_woman_category)
# Out:
# Marie Curie, née Sklodowska
# Physics

# %%
# Determine repeat winners
count_of_wins = df["full_name"].value_counts()
repeats = count_of_wins[count_of_wins >= 2].index
repeat_list = list(repeats)
print(repeat_list)
# Out:
# ['Comité international de la Croix Rouge (International Committee of the Red Cross)', 'Linus Carl Pauling', 'John Bardeen', 'Frederick Sanger', 'Marie Curie, née Sklodowska', 'Office of the United Nations High Commissioner for Refugees (UNHCR)']
